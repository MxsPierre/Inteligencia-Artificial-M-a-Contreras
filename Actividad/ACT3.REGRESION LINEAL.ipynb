# %% [markdown]
# <a href="https://colab.research.google.com/github/MxsPierre/Inteligencia-Artificial-M-a-Contreras/blob/main/ACT3.REGRESION%20LINEAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#REGRESION LINEAL
#MIA CONTRERAS, 2006081
#N4

# %%
# Cargar librerías
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
# Cargar datos
np.random.seed(0)
horas_estudio = np.random.rand(100, 1) * 10
calificaciones = 2 * horas_estudio + np.random.randn(100,1) * 2

# %%
# Preprocesamiento de datos
train_data, test_data, train_labels, test_labels = train_test_split(horas_estudio, calificaciones, test_size=0.2, random_state=42)

# %%
# Prueba de modelo
predicciones = modelo.predict(test_data)

# %%
# Selección y entrenamiento del modelo
modelo = LinearRegression()
modelo.fit(train_data, train_labels)
# Out:
# LinearRegression()

# %%
# Visualización de resultados
plt.scatter(test_data, test_labels, color='blue')
plt.plot(test_data, predicciones, color='red', linewidth=3)
plt.title('Modelo de Regresión Lineal')
plt.xlabel('Horas de Estudio')
plt.ylabel('Calificaciones')
plt.show()

# %%
# Evaluación del modelo
mse = mean_squared_error(test_labels, predicciones)
print("Error cuadrático medio:", mse)
# Out:
# Error cuadrático medio: 3.671012987885716
