# %% [markdown]
# <a href="https://colab.research.google.com/github/MxsPierre/Inteligencia-Artificial-M-a-Contreras/blob/main/ACTIVIDAD6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ACTIVIDAD 6
#MIA CONTRERAS, 2006081, N4

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.utils import to_categorical

(train_data, train_labels), (test_data, test_labels) = mnist.load_data()

# Preprocesamiento de datos
train_data = train_data.reshape((60000, 28, 28, 1)).astype('float32') / 255
test_data = test_data.reshape((10000, 28, 28, 1)).astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

for i in range(5):
    plt.imshow(train_data[i].reshape(28, 28), cmap='gray')
    plt.title(f"Etiqueta: {np.argmax(train_labels[i])}")
    plt.show()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Definir la arquitectura de la CNN
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(train_data, train_labels, epochs=10, batch_size=128, validation_split=0.2)

test_loss, test_acc = model.evaluate(test_data, test_labels)
print(f"Precisión en el conjunto de prueba: {test_acc}")

predictions = model.predict(test_data)

for i in range(5):
    plt.imshow(test_data[i].reshape(28, 28), cmap='gray')
    plt.title(f"Predicción: {np.argmax(predictions[i])}, Valor Real: {np.argmax(test_labels[i])}")
    plt.show()
# Out:
# Epoch 1/10
# 375/375 [==============================] - 45s 109ms/step - loss: 0.3566 - accuracy: 0.8913 - val_loss: 0.0836 - val_accuracy: 0.9738
# Epoch 2/10
# 375/375 [==============================] - 40s 106ms/step - loss: 0.1134 - accuracy: 0.9661 - val_loss: 0.0591 - val_accuracy: 0.9832
# Epoch 3/10
# 375/375 [==============================] - 41s 109ms/step - loss: 0.0854 - accuracy: 0.9749 - val_loss: 0.0467 - val_accuracy: 0.9866
# Epoch 4/10
# 375/375 [==============================] - 42s 112ms/step - loss: 0.0694 - accuracy: 0.9785 - val_loss: 0.0421 - val_accuracy: 0.9876
# Epoch 5/10
# 375/375 [==============================] - 42s 112ms/step - loss: 0.0578 - accuracy: 0.9821 - val_loss: 0.0400 - val_accuracy: 0.9886
# Epoch 6/10
# 375/375 [==============================] - 40s 107ms/step - loss: 0.0516 - accuracy: 0.9841 - val_loss: 0.0382 - val_accuracy: 0.9895
# Epoch 7/10
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout

# Definir la arquitectura de la ANN
ann_model = Sequential([
    Flatten(input_shape=(28, 28, 1)),
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

ann_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

ann_history = ann_model.fit(train_data, train_labels, epochs=10, batch_size=128, validation_split=0.2)

ann_test_loss, ann_test_acc = ann_model.evaluate(test_data, test_labels)
print(f"Precisión en el conjunto de prueba: {ann_test_acc}")

ann_predictions = ann_model.predict(test_data)

for i in range(5):
    plt.imshow(test_data[i].reshape(28, 28), cmap='gray')
    plt.title(f"Predicción: {np.argmax(ann_predictions[i])}, Valor Real: {np.argmax(test_labels[i])}")
    plt.show()
# Out:
# Epoch 1/10
# 375/375 [==============================] - 7s 16ms/step - loss: 0.3017 - accuracy: 0.9103 - val_loss: 0.1250 - val_accuracy: 0.9632
# Epoch 2/10
# 375/375 [==============================] - 7s 19ms/step - loss: 0.1189 - accuracy: 0.9638 - val_loss: 0.0931 - val_accuracy: 0.9707
# Epoch 3/10
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0818 - accuracy: 0.9750 - val_loss: 0.0873 - val_accuracy: 0.9738
# Epoch 4/10
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0637 - accuracy: 0.9796 - val_loss: 0.0816 - val_accuracy: 0.9757
# Epoch 5/10
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0485 - accuracy: 0.9839 - val_loss: 0.0860 - val_accuracy: 0.9744
# Epoch 6/10
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0419 - accuracy: 0.9862 - val_loss: 0.0793 - val_accuracy: 0.9783
# Epoch 7/10
# ...

# %%
#¿Cuántas épocas usaste para mejorar el rendimiento del modelo en comparación
#con la red neuronal prealimentada de la actividad 5?
#Se utilizaron 10 épocas para entrenar tanto la Red Neuronal
#Convolucional (CNN) como la Red Neuronal Artificial (ANN).

# %%
#¿Obtuviste un mejor rendimiento con este modelo o con el de la actividad 5?
#¿Por qué?
#Si, esto por que las CNN están específicamente
#diseñadas para tareas de procesamiento de imágenes, lo que permite
#capturar mejor las características espaciales e invariancias de traslación
#en las imágenes. En contraste, las ANN no son tan eficientes en este
#tipo de tareas. La arquitectura de las CNN las hace más adecuadas para
#clasificar imágenes como las del conjunto de datos MNIST.
